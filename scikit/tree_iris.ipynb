# %% [markdown]
# <a href="https://colab.research.google.com/github/codeplanets/ml_basic/blob/main/scikit/tree_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Scikit-learn**
#
# ## 붓꽃 데이터를 이용해서 의사결정나무를 만드는 코드

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

def main() :
  # load iris data
  dataset = datasets.load_iris()

  features = dataset.data
  targets = dataset.target

  petal_features = features[:, 2:]

  cIris = DecisionTreeClassifier(criterion='entropy', max_depth=3)
  cIris.fit(petal_features, targets)

  with open('iris-dtree.dot', mode='w') as f:
    tree.export_graphviz(cIris, out_file=f)

if __name__ == '__main__':
  main()

# %% [markdown]
# ![iris-dtree.png](data:image/png;base64,...)
